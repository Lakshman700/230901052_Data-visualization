# %%
import matplotlib.pyplot as plt
import numpy as np
xpoints=np.array([0,10])
ypoints=np.array([20,100])
print(plt.plot(xpoints,ypoints))
print(plt.show())
# Out:
# [<matplotlib.lines.Line2D object at 0x168988410>]
# None

# %%
x=np.array([0,5])
y=np.array([0,25])
print(plt.plot(x,y,marker='p'))
print(plt.show())
# Out:
# [<matplotlib.lines.Line2D object at 0x168addca0>]
# None

# %%
xpoints=([1,2,6,8])
ypoints=([3,8,1,10])
print(plt.plot(xpoints,ypoints))
print(plt.show())
# Out:
# [<matplotlib.lines.Line2D object at 0x168add640>]
# None

# %%
ypoints=np.array([5,7,1,0,3])
print(plt.plot(ypoints))
print(plt.show())
# Out:
# [<matplotlib.lines.Line2D object at 0x1689d9b80>]
# None

# %%
xpoints=np.array([3,6,9,2,7])
ypoints=np.array([2,3,5,6,3])
print(plt.plot(xpoints,ypoints,marker='p'))
print(plt.show())
# Out:
# [<matplotlib.lines.Line2D object at 0x168954da0>]
# None
